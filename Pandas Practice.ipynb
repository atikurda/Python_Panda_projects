# %% [markdown]
# ## Please use notebook to practice.. I have attached screenshots of the outputs for your reference. Make sure to recap what you learned during the classes. Don't worry if you wont get everyting correct. We will be doing solution together on Week 13. There is an optional part if you want to challange yourself. You may need to search online about groupby() function before attemping.

# %% [markdown]
# ### Import Pandas Library

# %%
import pandas as pd

# %%
ecom = pd.read_csv('data.csv',encoding= 'unicode_escape')

# %% [markdown]
# **Check the head of the DataFrame.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
ecom.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
ecom.head(1)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom

# %%
ecom.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...

# %% [markdown]
# **Check the last 10 rows of the DataFrame.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
ecom.tail(10)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541899    581587     22726       ALARM CLOCK BAKELIKE GREEN         4
# 541900    581587     22730       ALARM CLOCK BAKELIKE IVORY         4
# 541901    581587     22367  CHILDRENS APRON SPACEBOY DESIGN         8
# 541902    581587     22629              SPACEBOY LUNCH BOX         12
# 541903    581587     23256      CHILDRENS CUTLERY SPACEBOY          4
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541899  12/9/2011 12:50       3.75     12680.0  France
# 541900  12/9/2011 12:50       3.75     12680.0  France
# ...

# %% [markdown]
# **How many rows and columns are there?**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# **Show the statistical measurements of ecom dataset**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
ecom.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
#std = standart deviation

# %%
#If mean value is less than std, in this case look for outliers. 
# outliers can be identified using boxplot

# %% [markdown]
# **Show the column names in dataset**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
ecom.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
ecom.columns.values
# Out:
# array(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'], dtype=object)

# %% [markdown]
# **What is the average Unit Price?**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
ecom.UnitPrice.mean()
# Out:
# 4.611113626083471

# %%
ecom["UnitPrice"].mean()
# Out:
# 4.611113626083471

# %% [markdown]
# **What were the highest and lowest unit prices?**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
ecom["UnitPrice"].max()
# Out:
# 38970.0

# %%
ecom.UnitPrice.max()
# Out:
# 38970.0

# %%
ecom["UnitPrice"].sort_values()
# Out:
# 299984   -11062.06
# 299983   -11062.06
# 40984         0.00
# 52217         0.00
# 52262         0.00
#             ...
# 16356     13541.33
# 43703     16453.71
# 43702     16888.02
# 524602    17836.46
# 222681    38970.00
# Name: UnitPrice, Length: 541909, dtype: float64

# %%
ecom["UnitPrice"].sort_values(ascending=False).head(1)
# Out:
# 222681    38970.0
# Name: UnitPrice, dtype: float64

# %%
ecom.sort_values(by="UnitPrice", ascending=False).head(1)
# Out:
#        InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 222681   C556445         M      Manual        -1  6/10/2011 15:31    38970.0
#
#         CustomerID         Country
# 222681     15098.0  United Kingdom

# %%
ecom.iloc[222681]
# Out:
# InvoiceNo              C556445
# StockCode                    M
# Description             Manual
# Quantity                    -1
# InvoiceDate    6/10/2011 15:31
# UnitPrice              38970.0
# CustomerID             15098.0
# Country         United Kingdom
# Name: 222681, dtype: object

# %%
ecom.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
ecom["UnitPrice"].agg(['min', 'max'])
#display min and max using single line of code
# Out:
# min   -11062.06
# max    38970.00
# Name: UnitPrice, dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
ecom.UnitPrice.min()
# Out:
# -11062.06

# %%
ecom["UnitPrice"].min()
# Out:
# -11062.06

# %%
ecom["UnitPrice"].sort_values().head(1)
# Out:
# 299984   -11062.06
# Name: UnitPrice, dtype: float64

# %%
ecom.iloc[299984]
# Out:
# InvoiceNo              A563187
# StockCode                    B
# Description    Adjust bad debt
# Quantity                     1
# InvoiceDate    8/12/2011 14:52
# UnitPrice            -11062.06
# CustomerID                 NaN
# Country         United Kingdom
# Name: 299984, dtype: object

# %%
ecom.sort_values(by="UnitPrice").head(1)
# Out:
#        InvoiceNo StockCode      Description  Quantity      InvoiceDate  \
# 299984   A563187         B  Adjust bad debt         1  8/12/2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299984  -11062.06         NaN  United Kingdom

# %% [markdown]
# **Check missing values in each column**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
ecom.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
ecom.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
ecom.isnull()
# Out:
#         InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0           False      False        False     False        False      False
# 1           False      False        False     False        False      False
# 2           False      False        False     False        False      False
# 3           False      False        False     False        False      False
# 4           False      False        False     False        False      False
# ...           ...        ...          ...       ...          ...        ...
# 541904      False      False        False     False        False      False
# 541905      False      False        False     False        False      False
# 541906      False      False        False     False        False      False
# 541907      False      False        False     False        False      False
# 541908      False      False        False     False        False      False
#
#         CustomerID  Country
# ...

# %%
ecom.isnull().any()
# Out:
# InvoiceNo      False
# StockCode      False
# Description     True
# Quantity       False
# InvoiceDate    False
# UnitPrice      False
# CustomerID      True
# Country        False
# dtype: bool

# %%
ecom.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
ecom.isnull().sum().sum()
# Out:
# 136534

# %% [markdown]
# ### Below code displays ratio of null values to entire rows in dataset.

# %%
ecom.shape
# Out:
# (541909, 8)

# %%
ecom.shape[0]
# Out:
# 541909

# %%
ecom.isnull().sum().sum()/ecom.shape[0]*100
#percentage of null rows in this dataset
# Out:
# 25.195005065426113

# %% [markdown]
# #### As you can see, there are only around %25 of null values.

# %%
ecom[ecom["Description"].isnull()==True]
# Out:
#        InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 622       536414     22139         NaN        56  12/1/2010 11:52        0.0
# 1970      536545     21134         NaN         1  12/1/2010 14:32        0.0
# 1971      536546     22145         NaN         1  12/1/2010 14:33        0.0
# 1972      536547     37509         NaN         1  12/1/2010 14:33        0.0
# 1987      536549    85226A         NaN         1  12/1/2010 14:34        0.0
# ...          ...       ...         ...       ...              ...        ...
# 535322    581199     84581         NaN        -2  12/7/2011 18:26        0.0
# 535326    581203     23406         NaN        15  12/7/2011 18:31        0.0
# 535332    581209     21620         NaN         6  12/7/2011 18:35        0.0
# 536981    581234     72817         NaN        27  12/8/2011 10:33        0.0
# 538554    581408     85175         NaN        20  12/8/2011 14:06        0.0
#
#         CustomerID         Country
# ...

# %%
ecom[ecom["CustomerID"].isnull()==True]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 622     12/1/2010 11:52       0.00         NaN  United Kingdom
# ...

# %%
ecom[(ecom["Description"].isnull()==True)&(ecom["CustomerID"].isnull()==True)]
# Out:
#        InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 622       536414     22139         NaN        56  12/1/2010 11:52        0.0
# 1970      536545     21134         NaN         1  12/1/2010 14:32        0.0
# 1971      536546     22145         NaN         1  12/1/2010 14:33        0.0
# 1972      536547     37509         NaN         1  12/1/2010 14:33        0.0
# 1987      536549    85226A         NaN         1  12/1/2010 14:34        0.0
# ...          ...       ...         ...       ...              ...        ...
# 535322    581199     84581         NaN        -2  12/7/2011 18:26        0.0
# 535326    581203     23406         NaN        15  12/7/2011 18:31        0.0
# 535332    581209     21620         NaN         6  12/7/2011 18:35        0.0
# 536981    581234     72817         NaN        27  12/8/2011 10:33        0.0
# 538554    581408     85175         NaN        20  12/8/2011 14:06        0.0
#
#         CustomerID         Country
# ...

# %%
#When Description column is null then CustomerId is also null.

# %%
ecom[ecom["Description"].isnull()==True]["UnitPrice"].mean()
# Out:
# 0.0

# %%
ecom[ecom["CustomerID"].isnull()==True]["UnitPrice"].mean()
# Out:
# 8.076576917380557

# %%
##Fill in null values

# %% [markdown]
# #### Check the shape of your dataset before dropping null values.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
ecom.shape
# Out:
# (541909, 8)

# %%
ecom.dropna().shape
# Out:
# (406829, 8)

# %% [markdown]
# **Drop null values. Use "inplace=True" argument**

# %%
#your code here
ecom.dropna()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
ecom.shape
# Out:
# (541909, 8)

# %%
ecom.dropna(inplace=True)

# %% [markdown]
# #### Check the shape of your dataset after dropping null values.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ecom.shape
# Out:
# (406829, 8)

# %% [markdown]
# **List the country names and number of records belongs to each country**

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
#your code here
ecom["Country"].value_counts()
# Out:
# United Kingdom          361878
# Germany                   9495
# France                    8491
# EIRE                      7485
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               1877
# Portugal                  1480
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# USA                        291
# Israel                     250
# Unspecified                244
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# ...

# %%
ecom[ecom["Country"]=="Unspecified"]
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 152712    549687     20685               DOORMAT RED RETROSPOT         2
# 152713    549687     22691             DOORMAT WELCOME SUNRISE         2
# 152714    549687     48116          DOORMAT MULTICOLOUR STRIPE         2
# 152715    549687     21213         PACK OF 72 SKULL CAKE CASES        24
# 152716    549687     21977  PACK OF 60 PINK PAISLEY CAKE CASES        24
# ...          ...       ...                                 ...       ...
# 308810    564051     23007              SPACEBOY BABY GIFT SET         1
# 308811    564051     21833                CAMOUFLAGE LED TORCH        12
# 308812    564051     23081       GREEN METAL BOX ARMY SUPPLIES         2
# 308813    564051     23046   PAPER LANTERN 9 POINT DELUXE STAR         2
# 308814    564051     23045    PAPER LANTERN 5 POINT STAR MOON          4
#
#             InvoiceDate  UnitPrice  CustomerID      Country
# ...

# %% [markdown]
# **How many records are as Country United Kingdom?**

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
#your code here
ecom[ecom["Country"]=="United Kingdom"].count()
# Out:
# InvoiceNo      361878
# StockCode      361878
# Description    361878
# Quantity       361878
# InvoiceDate    361878
# UnitPrice      361878
# CustomerID     361878
# Country        361878
# dtype: int64

# %% [markdown]
# ### Whats the average Unit Price without United Kingdom?

# %%
ecom["UnitPrice"].mean()
# Out:
# 3.4604710185298773

# %%
#[12:08] Mohammad Mrida
#Avg price for United Kingdom
ecom[ecom["Country"]=="United Kingdom"]["UnitPrice"].mean()
# Out:
# 3.2560068973474823

# %%
ecom[ecom["Country"] != "United Kingdom"]["UnitPrice"].mean()
# Out:
# 5.1065093101384

# %% [markdown]
# ### Average UnitPrice per Country

# %%
ecom.groupby(["Country"])["UnitPrice"].mean().sort_values()
# Out:
# Country
# USA                       2.216426
# Japan                     2.276145
# Saudi Arabia              2.411000
# Iceland                   2.644011
# Netherlands               2.738317
# Lithuania                 2.841143
# Czech Republic            2.938333
# Unspecified               3.200820
# Australia                 3.220612
# United Kingdom            3.256007
# Denmark                   3.256941
# United Arab Emirates      3.380735
# Switzerland               3.499521
# Belgium                   3.644335
# Israel                    3.650000
# Sweden                    3.910887
# Germany                   3.966930
# Poland                    4.170880
# Austria                   4.243192
# RSA                       4.277586
# Brazil                    4.456250
# Bahrain                   4.644118
# European Community        4.820492
# Italy                     4.831121
# Greece                    4.885548
# Channel Islands           4.932124
# ...

# %%
ecom[ecom["Country"]=="Singapore"]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 70758     542102     21519   GIN & TONIC DIET GREETING CARD         72
# 70759     542102     22697   GREEN REGENCY TEACUP AND SAUCER         6
# 70760     542102     22699  ROSES REGENCY TEACUP AND SAUCER          6
# 70761     542102     22343    PARTY PIZZA DISH RED RETROSPOT        24
# 70762     542102     22344    PARTY PIZZA DISH PINK POLKADOT        24
# ...          ...       ...                               ...       ...
# 398370    571239     21888                         BINGO SET        12
# 406404   C571750         M                            Manual        -1
# 406405   C571750         M                            Manual        -1
# 406406    571751         M                            Manual         1
# 406407    571751         M                            Manual         1
#
#              InvoiceDate  UnitPrice  CustomerID    Country
# ...

# %%
ecom[ecom["Country"]=="Singapore"]["UnitPrice"].value_counts().sort_values(ascending=False)
# Out:
# 1.25       23
# 4.15       15
# 0.85       14
# 2.95       13
# 3.75       12
# 2.10       10
# 2.55       10
# 0.72        8
# 6.75        8
# 2.08        8
# 0.42        7
# 5.95        7
# 1.65        7
# 1.45        6
# 0.55        5
# 7.08        4
# 0.21        4
# 1.95        4
# 3.25        4
# 0.83        4
# 8.50        4
# 0.36        4
# 7.65        3
# 0.39        3
# 0.29        3
# 5.45        2
# 1252.95     2
# 239.30      2
# 2382.92     2
# 2118.74     2
# 10.95       2
# 4.95        2
# 162.60      2
# 2053.07     2
# 0.19        2
# 2.25        2
# 3949.32     2
# 1.69        2
# 1.49        1
# 125.00      1
# 65.00       1
# 8.25        1
# 0.65        1
# 11.15       1
# 6.95        1
# 2.89        1
# 4.25        1
# 6.35        1
# 3.95        1
# 7.50        1
# 6.25        1
# Name: UnitPrice, dtype: int64

# %%
ecom[ecom["Country"]=="Singapore"]["UnitPrice"].value_counts().sort_index(ascending=False)
# Out:
# 3949.32     2
# 2382.92     2
# 2118.74     2
# 2053.07     2
# 1252.95     2
# 239.30      2
# 162.60      2
# 125.00      1
# 65.00       1
# 11.15       1
# 10.95       2
# 8.50        4
# 8.25        1
# 7.65        3
# 7.50        1
# 7.08        4
# 6.95        1
# 6.75        8
# 6.35        1
# 6.25        1
# 5.95        7
# 5.45        2
# 4.95        2
# 4.25        1
# 4.15       15
# 3.95        1
# 3.75       12
# 3.25        4
# 2.95       13
# 2.89        1
# 2.55       10
# 2.25        2
# 2.10       10
# 2.08        8
# 1.95        4
# 1.69        2
# 1.65        7
# 1.49        1
# 1.45        6
# 1.25       23
# 0.85       14
# 0.83        4
# 0.72        8
# 0.65        1
# 0.55        5
# 0.42        7
# 0.39        3
# 0.36        4
# 0.29        3
# 0.21        4
# 0.19        2
# Name: UnitPrice, dtype: int64

# %%
#[12:23] Mohammad Mrida
# Total unitprice per Country
ecom.groupby(["Country"])["UnitPrice"].sum().sort_values(ascending=False).head(10)
# Out:
# Country
# United Kingdom    1178277.264
# France              42871.240
# EIRE                38253.580
# Germany             37666.000
# Singapore           25108.890
# Portugal            12929.860
# Spain               12633.450
# Belgium              7540.130
# Switzerland          6568.600
# Norway               6529.060
# Name: UnitPrice, dtype: float64

# %% [markdown]
# **Create a column named Total which shows the total amount of spend using UnitPrice and Quantity ?**

# %% [markdown]
# Hint: You can search online "create new column using other columns pandas"
# ("https://sparkbyexamples.com/pandas/pandas-add-column-based-on-another-column/")
# <p> Here is an example: df["NewColumnName"] = df["Column"] * df["Column"] <p\>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
ecom["Total"] = ecom["Quantity"] * ecom["UnitPrice"]

# %%
ecom.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Total
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34

# %%
#Total spending by country

# %%
ecom.groupby(["Country"])["Total"].sum().sort_values(ascending=False).head(5)
# Out:
# Country
# United Kingdom    6767873.394
# Netherlands        284661.540
# EIRE               250285.220
# Germany            221698.210
# France             196712.840
# Name: Total, dtype: float64

# %%
ecom.groupby(["Country"])["Total"].mean().sort_values(ascending=False).head(5)
# Out:
# Country
# Netherlands    120.059696
# Australia      108.877895
# Japan           98.716816
# Sweden          79.211926
# Denmark         48.247147
# Name: Total, dtype: float64

# %%
#[13:50] Rashedul Hasen

ecom.groupby(["Country"])["Total"].sum().reset_index(name='Total').sort_values(by="Total", ascending=False).head()
# Out:
#            Country        Total
# 35  United Kingdom  6767873.394
# 23     Netherlands   284661.540
# 10            EIRE   250285.220
# 14         Germany   221698.210
# 13          France   196712.840

# %% [markdown]
# ### Highest Total by Customer in sum and average

# %%
ecom.groupby(["CustomerID"])["Total"].sum().sort_values(ascending=False).head()
# Out:
# CustomerID
# 14646.0    279489.02
# 18102.0    256438.49
# 17450.0    187482.17
# 14911.0    132572.62
# 12415.0    123725.45
# Name: Total, dtype: float64

# %%
ecom.groupby(["CustomerID"])["Total"].mean().sort_values(ascending=False).head()
# Out:
# CustomerID
# 15195.0    3861.000000
# 13135.0    3096.000000
# 17846.0    2033.100000
# 16532.0    1687.200000
# 15749.0    1435.726667
# Name: Total, dtype: float64

# %% [markdown]
# **Which Country spend least in total?**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
ecom.groupby(["Country"])["Total"].sum().sort_values().head().reset_index(name="Total")
# Out:
#         Country   Total
# 0  Saudi Arabia  131.17

# %%
ecom["Country"]
# Out:
# 0         United Kingdom
# 1         United Kingdom
# 2         United Kingdom
# 3         United Kingdom
# 4         United Kingdom
#                ...
# 541904            France
# 541905            France
# 541906            France
# 541907            France
# 541908            France
# Name: Country, Length: 406829, dtype: object

# %%
ecom.groupby(["Country"])["Total"].sum().sort_values(ascending=False).tail(1)
# Out:
# Country
# Saudi Arabia    131.17
# Name: Total, dtype: float64

# %% [markdown]
# **What is the max Total spending in whole dataset and show the records of that spending ?**
# <p>Hint: You can use loc and idxmax<p\>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#your code here
ecom[ecom["Total"] == ecom["Total"].max()]
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#            InvoiceDate  UnitPrice  CustomerID         Country     Total
# 540421  12/9/2011 9:15       2.08     16446.0  United Kingdom  168469.6

# %%
ecom["Total"].max()
# Out:
# 168469.6

# %%
ecom.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Total
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34

# %%
ecom.iloc[[11]]
# Out:
#    InvoiceNo StockCode                Description  Quantity     InvoiceDate  \
# 11    536367     22748  POPPY'S PLAYHOUSE KITCHEN         6  12/1/2010 8:34
#
#     UnitPrice  CustomerID         Country  Total
# 11        2.1     13047.0  United Kingdom   12.6

# %%
ecom["Total"].idxmax()
# Out:
# 540421

# %%
print(type(ecom["Total"].idxmax()))
# Out:
# <class 'numpy.int64'>

# %%
ecom.loc[[ecom.Total.idxmax()]]
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#            InvoiceDate  UnitPrice  CustomerID         Country     Total
# 540421  12/9/2011 9:15       2.08     16446.0  United Kingdom  168469.6

# %% [markdown]
# **How many people who live in Spain spend more than average Total ?**

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
#your code here 2 filtering 1)spain and 2)avg

# %%
ecom[ecom["Country"]=="Spain"]
# Out:
#        InvoiceNo StockCode                    Description  Quantity  \
# 6421      536944     22383        LUNCH BAG SUKI  DESIGN         70
# 6422      536944     22384        LUNCH BAG PINK POLKADOT       100
# 6423      536944     20727        LUNCH BAG  BLACK SKULL.        60
# 6424      536944     20725        LUNCH BAG RED RETROSPOT        70
# 6425      536944     20728            LUNCH BAG CARS BLUE       100
# ...          ...       ...                            ...       ...
# 535271    581193     23291       DOLLY GIRL CHILDRENS CUP         2
# 535272    581193    85232D  SET/3 DECOUPAGE STACKING TINS         1
# 535273    581193     22721  SET OF 3 CAKE TINS SKETCHBOOK         2
# 535274    581193     23241   TREASURE TIN GYMKHANA DESIGN         1
# 535275    581193     23247     BISCUIT TIN 50'S CHRISTMAS         1
#
#             InvoiceDate  UnitPrice  CustomerID Country   Total
# 6421    12/3/2010 12:20       1.65     12557.0   Spain  115.50
# ...

# %%
ecom.Total.mean()
# Out:
# 20.401853884564613

# %%
ecom[(ecom["Country"]=="Spain") & (ecom["Total"]>ecom["Total"].mean())].count()
# Out:
# InvoiceNo      528
# StockCode      528
# Description    528
# Quantity       528
# InvoiceDate    528
# UnitPrice      528
# CustomerID     528
# Country        528
# Total          528
# dtype: int64

# %%
ecom[(ecom["Country"]=="Spain") & (ecom["Total"]>ecom["Total"].mean())]["Country"].count()
# Out:
# 528

# %% [markdown]
# ### Optional
# <p>This part is optional. You need to know .groupby() function in Panads to complete.<p\>

# %% [markdown]
# **Show total spending amount according to the Countries**

# %%
#[15:21] Mayowa Bamiro

ecom.groupby(["Country"])["Total"].sum()
# Out:
# Country
# Australia                137077.270
# Austria                   10154.320
# Bahrain                     548.400
# Belgium                   40910.960
# Brazil                     1143.600
# Canada                     3666.380
# Channel Islands           20086.290
# Cyprus                    12946.290
# Czech Republic              707.720
# Denmark                   18768.140
# EIRE                     250285.220
# European Community         1291.750
# Finland                   22326.740
# France                   196712.840
# Germany                  221698.210
# Greece                     4710.520
# Iceland                    4310.000
# Israel                     6994.250
# Italy                     16890.510
# Japan                     35340.620
# Lebanon                    1693.880
# Lithuania                  1661.060
# Malta                      2505.470
# Netherlands              284661.540
# Norway                    35163.460
# Poland                     7213.140
# ...

# %%
ecom.groupby(["Country"])["Total"].sum().sort_values().tail()
# Out:
# Country
# France             196712.840
# Germany            221698.210
# EIRE               250285.220
# Netherlands        284661.540
# United Kingdom    6767873.394
# Name: Total, dtype: float64

# %% [markdown]
# **Calculate average of spending according to country with apply function?**

# %%
ecom.groupby(["Country"])["Total"].mean()
# Out:
# Country
# Australia               108.877895
# Austria                  25.322494
# Bahrain                  32.258824
# Belgium                  19.773301
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          26.499063
# Cyprus                   20.813971
# Czech Republic           23.590667
# Denmark                  48.247147
# EIRE                     33.438239
# European Community       21.176230
# Finland                  32.124806
# France                   23.167217
# Germany                  23.348943
# Greece                   32.263836
# Iceland                  23.681319
# Israel                   27.977000
# Italy                    21.034259
# Japan                    98.716816
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    19.728110
# Netherlands             120.059696
# Norway                   32.378877
# Poland                   21.152903
# ...

# %%
import numpy as np #numpy = numerical python

# %%
ecom.groupby("Country")["Total"].apply(np.mean)
# Out:
# Country
# Australia               108.877895
# Austria                  25.322494
# Bahrain                  32.258824
# Belgium                  19.773301
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          26.499063
# Cyprus                   20.813971
# Czech Republic           23.590667
# Denmark                  48.247147
# EIRE                     33.438239
# European Community       21.176230
# Finland                  32.124806
# France                   23.167217
# Germany                  23.348943
# Greece                   32.263836
# Iceland                  23.681319
# Israel                   27.977000
# Italy                    21.034259
# Japan                    98.716816
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    19.728110
# Netherlands             120.059696
# Norway                   32.378877
# Poland                   21.152903
# ...

# %% [markdown]
# # Congrats!

# %%
df = pd.read_csv("GDP (nominal) per Capita.csv",encoding= 'unicode_escape',  index_col=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("GDP (nominal) per Capita.csv",encoding= 'unicode_escape',  index_col=0)
#
# NameError: name 'pd' is not defined
